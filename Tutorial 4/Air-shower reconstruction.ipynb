# %% [markdown]
# # Air-shower reconstruction using a fully-connected network
# ## Cosmic-ray observatory
# In this example, we will train a neural network to reconstruct air-shower properties measured by a hypothetic cosmic-ray observatory located at a height of 1400 m. The observatory features a cartesian array of 14 x 14 particle detectors with a distance of 750 m.
# Thus, the measured data contain the simulated detector responses from secondary particles of the cosmic-ray induced air shower that interact with the ground-based observatory.
#
# Each particle detector measures two quantities that are stored in the form of a cartesian image (2D array with 14 x 14 pixels)
# - arrival time `T`: arrival time of the first particles
# - signal `S`: integrated signal
#
# In this task, we are interested in reconstructing the cosmic-ray energy in EeV (exaelectronvolt = $10^{18}~\mathrm{eV}$) using the measured particle footprint and a fully-connected network.
#
# The tutorial is inspired by the simulation and the study performed in https://doi.org/10.1016/j.astropartphys.2017.10.006.

# %%
import tensorflow as tf
import keras
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

layers = keras.layers

print("keras", keras.__version__)
print("tf", tf.__version__)
# Out:
# keras 2.15.0
# tf 2.15.0

# %% [markdown]
# ---
# # Data
# ### Download data
# As a first step, we have to download the simulated air shower data.

# %%
import os
path = r"/Users/murilo/Downloads/Tutorials-20231205/Tutorial 4/airshowers_mnist.npz"

f = np.load(path)

# %% [markdown]
# ### Input 1: Arrival times
# Our first input is the arrival times of the first shower particles, measured at the various stations. We normalize the arrival times with respect to the mean and the standard deviation of the arrival time distribution. Remember that each input has the shape of 14 x 14, as each station measures a specific arrival time.

# %%
# time map
T = f['time']
T -= np.nanmean(T)
T /= np.nanstd(T)
T[np.isnan(T)] = 0

print(T.shape)
# Out:
# (100000, 14, 14)

# %% [markdown]
# #### Plot four example maps
# To visualize a map of arrival times, we can plot a random example event. Here, the dark blue indicates an early trigger and a bright yellow a late trigger.
# With this information, one can directly get an impression of the shower axis (arrival direction) of the arriving particle shower.

# %%
nsamples=len(T)
random_samples = np.random.choice(nsamples, 4)

def rectangular_array(n=14):
    """ Return x,y coordinates for rectangular array with n^2 stations. """
    n0 = (n - 1) / 2
    return (np.mgrid[0:n, 0:n].astype(float) - n0)

plt.figure(figsize=(9,7))

for i,j in enumerate(random_samples):
    plt.subplot(2,2,i+1)
    footprint=T[j,...]
    xd, yd = rectangular_array()
    mask = footprint != 0
    mask[5, 5] = True
    marker_size = 50 * footprint[mask]
    plot = plt.scatter(xd, yd, c='grey', s=10, alpha=0.3, label="silent")
    circles = plt.scatter(xd[mask], yd[mask], c=footprint[mask], 
                          cmap="viridis", alpha=1, label="loud",
                          edgecolors="k", linewidths=0.3)
    cbar = plt.colorbar(circles)
    cbar.set_label('normalized time [a.u.]')
    plt.xlabel("x / km")
    plt.ylabel("y / km")
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Input 2: Measured signals
# In the following, we inspect the measured signals of the detectors. Again, we have 14 x 14 measurements (a few are zero as no signal was measured) that form a single event. We process the signal using a logarithmic re-scaling.

# %%
# signal map
S = f['signal']
S = np.log10(1 + S) # 1 is to avoid dealing with zero values
# normalize
S -= np.nanmin(S) # subtract min
S /= np.nanmax(S) # divide by max
S[np.isnan(S)] = 0 # every nan (not a number) set to zero

print(S.shape)
# Out:
# (100000, 14, 14)

# %% [markdown]
# #### Plot four example events

# %%
plt.figure(figsize=(9,7))

for i,j in enumerate(random_samples):
    plt.subplot(2,2,i+1)
    footprint=S[j,...]
    xd, yd = rectangular_array()
    mask = footprint != 0
    mask[5, 5] = True
    print(mask.shape)
    marker_size = 130 * footprint[mask] + 20
    plot = plt.scatter(xd, yd, c='grey', s=10, alpha=0.4, label="silent")
    circles = plt.scatter(xd[mask], yd[mask], c=footprint[mask], s=marker_size,
                          cmap="autumn_r", alpha=1, label="loud",
                          edgecolors="k", linewidths=0.4)
    cbar = plt.colorbar(circles)
    cbar.set_label('normalized signals [a.u.]')
    plt.xlabel("x / km")
    plt.ylabel("y / km")
    plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)

# %% [markdown]
# ### Labels
# Now, we can prepare the targets of our neural network training.

# %%
axis = f['showeraxis']

# %%
core = f['showercore'][:, 0:2]
core /= 750

# %%
# energy - log10(E/eV) in range 3 - 100 EeV
energy = f['energy']
print(energy)
# Out:
# [ 4.00461776  5.99159294  7.49367551 ... 10.81657107  5.07542798
#  43.32910954]

# %% [markdown]
# ---
# #### Training and test data
# We further split the data into one large training set and a smaller test set. This test set is used for the final evaluation of the model and is only used once to ensure an unbiased performance measure. Before, we combine our input `X` by concatenating the maps of arrival times with the maps of signals.

# %%
X = np.stack([T, S], axis=-1)
X.shape
# Out:
# (100000, 14, 14, 2)

# %%
X_train, X_test = np.split(X, [-20000])
print(X_train.shape)
print(X_test.shape)
energy_train, energy_test = np.split(energy, [-20000])
# Out:
# (80000, 14, 14, 2)
# (20000, 14, 14, 2)

# %% [markdown]
# ---
# ## Define Model
# Now, we will set up a neural network to reconstruct the energy of the particle shower. In this **define step** we will set the architecture of the model.
#
#
# > **Modification section**
# > Feel free to modify the model.
# > For example:
# > *   Change the number of nodes (but remember that the number of weights scales with n x n. Also, the final layer has to have only one node as we are reconstructing the energy, which is a scalar.).
# > *   Change the activation function, e.g., use `relu, tanh, sigmoid, softplus, elu, ` (take care to not use an activation function for the final layer!).
# > *   Add new layers.
# > * Increase the Dropout fraction or place Dropout between several layers if you observe overtraining (validation loss increases).

# %%
model = keras.models.Sequential(name="energy_regression_NN")

nb_nodes = 100

model.add(layers.Flatten(input_shape=X_train.shape[1:]))  # this layer re-arranges the 2D image to a vector, leave it as it is
model.add(layers.Dense(nb_nodes, activation="elu"))
# model.add(layers.Dropout(0.3))
model.add(layers.Dense(nb_nodes, activation="elu"))
# model.add(layers.Dropout(0.3))
model.add(layers.Dense(nb_nodes, activation="elu"))
# model.add(layers.Dropout(0.3))
model.add(layers.Dense(nb_nodes, activation="elu"))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(1))

# %% [markdown]
# We can have a deeper look at our designed model and inspect the number of adaptive parameters by printing the model `summary`.

# %%
print(model.summary())
# Out:
# Model: "energy_regression_NN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 392)               0
#
#  dense (Dense)               (None, 100)               39300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 100)               10100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_4 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 69701 (272.27 KB)
# Trainable params: 69701 (272.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# ### Compile
# We now compile the model to prepare it for the training. During the **compile** step, we set a loss/objective function (`mean_squared_error`, as energy reconstruction is a regression task) and set an optimizer. In this case, we use the Adam optimizer with a learning rate of 0.001.
# To monitor the resolution and the bias of the model, we add them as a metric.

# %%
def resolution(y_true, y_pred):
    """ Metric to control for standart deviation """
    mean, var = tf.nn.moments((y_true - y_pred), axes=[0])
    return tf.sqrt(var)


def bias(y_true, y_pred):
    """ Metric to control for standart deviation """
    mean, var = tf.nn.moments((y_true - y_pred), axes=[0])
    return mean

# %%
model.compile(
    loss='mean_squared_error',
    metrics=[bias, resolution],
    optimizer=keras.optimizers.legacy.Adam(learning_rate=1e-3))

# %% [markdown]
# ---
# ### Training
# We can now run the training for 20 `epochs` (20-fold iteration over the dataset) using our training data `X_train` and our energy labels `energy_train`.
# For each iteration (calculating the gradients, updating the model parameters), we use 128 samples (`batch_size`). We furthermore can set the fraction of validation data (initially set to `0.1`) that is used to monitor overtraining.
#
# > **Modification section**
# > Feel free to modify the training procedure, for example:
# >*   Change the number of `epochs`.
# >*   Modify the batch size via `batch_size`.

# %%
fit = model.fit(
    X_train,
    energy_train,
    batch_size=256,
    epochs=50,
    verbose=2,
    validation_split=0.1,
)
# Out:
# Epoch 1/50
# 282/282 - 1s - loss: 272.3520 - bias: 0.9057 - resolution: 13.8985 - val_loss: 50.7551 - val_bias: 2.1246 - val_resolution: 6.7383 - 828ms/epoch - 3ms/step
# Epoch 2/50
# 282/282 - 1s - loss: 35.9786 - bias: 0.1630 - resolution: 5.8609 - val_loss: 18.0859 - val_bias: 0.1316 - val_resolution: 4.2243 - 584ms/epoch - 2ms/step
# Epoch 3/50
# 282/282 - 1s - loss: 25.3400 - bias: 0.0833 - resolution: 4.9584 - val_loss: 16.6937 - val_bias: 0.7264 - val_resolution: 3.9734 - 579ms/epoch - 2ms/step
# Epoch 4/50
# 282/282 - 1s - loss: 21.6067 - bias: 0.0776 - resolution: 4.5794 - val_loss: 15.6178 - val_bias: 0.7976 - val_resolution: 3.8265 - 595ms/epoch - 2ms/step
# Epoch 5/50
# 282/282 - 1s - loss: 20.4470 - bias: 0.0721 - resolution: 4.4405 - val_loss: 14.6077 - val_bias: 0.6920 - val_resolution: 3.7466 - 575ms/epoch - 2ms/step
# Epoch 6/50
# 282/282 - 1s - loss: 19.0864 - bias: 0.0684 - resolution: 4.2773 - val_loss: 14.0938 - val_bias: -1.9727e-01 - val_resolution: 3.7146 - 579ms/epoch - 2ms/step
# Epoch 7/50
# 282/282 - 1s - loss: 17.1674 - bias: 0.0743 - resolution: 4.0712 - val_loss: 11.9539 - val_bias: 0.0163 - val_resolution: 3.4130 - 660ms/epoch - 2ms/step
# Epoch 8/50
# 282/282 - 1s - loss: 16.4410 - bias: 0.0687 - resolution: 3.9892 - val_loss: 15.8256 - val_bias: 0.6796 - val_resolution: 3.8807 - 585ms/epoch - 2ms/step
# Epoch 9/50
# 282/282 - 1s - loss: 16.1143 - bias: 0.0787 - resolution: 3.9316 - val_loss: 10.0116 - val_bias: 0.3455 - val_resolution: 3.1028 - 608ms/epoch - 2ms/step
# Epoch 10/50
# 282/282 - 1s - loss: 15.4147 - bias: 0.0728 - resolution: 3.8484 - val_loss: 11.5648 - val_bias: 0.3875 - val_resolution: 3.3212 - 591ms/epoch - 2ms/step
# Epoch 11/50
# 282/282 - 1s - loss: 15.7298 - bias: 0.0789 - resolution: 3.8870 - val_loss: 11.7884 - val_bias: -9.7113e-01 - val_resolution: 3.2456 - 598ms/epoch - 2ms/step
# Epoch 12/50
# 282/282 - 1s - loss: 14.9963 - bias: 0.0754 - resolution: 3.7946 - val_loss: 10.9813 - val_bias: -1.1959e-01 - val_resolution: 3.2690 - 591ms/epoch - 2ms/step
# Epoch 13/50
# 282/282 - 1s - loss: 14.7810 - bias: 0.0699 - resolution: 3.7625 - val_loss: 12.9946 - val_bias: 0.8827 - val_resolution: 3.4527 - 595ms/epoch - 2ms/step
# Epoch 14/50
# 282/282 - 1s - loss: 14.4682 - bias: 0.0710 - resolution: 3.7287 - val_loss: 9.9569 - val_bias: 0.0570 - val_resolution: 3.1077 - 586ms/epoch - 2ms/step
# Epoch 15/50
# 282/282 - 1s - loss: 14.1238 - bias: 0.0810 - resolution: 3.6829 - val_loss: 10.2575 - val_bias: -2.8780e-01 - val_resolution: 3.1403 - 582ms/epoch - 2ms/step
# Epoch 16/50
# 282/282 - 1s - loss: 14.3731 - bias: 0.0756 - resolution: 3.7268 - val_loss: 9.9819 - val_bias: 0.0769 - val_resolution: 3.1176 - 574ms/epoch - 2ms/step
# Epoch 17/50
# 282/282 - 1s - loss: 13.2452 - bias: 0.0814 - resolution: 3.5711 - val_loss: 11.5960 - val_bias: -6.3607e-03 - val_resolution: 3.3648 - 572ms/epoch - 2ms/step
# Epoch 18/50
# 282/282 - 1s - loss: 13.4606 - bias: 0.0793 - resolution: 3.6124 - val_loss: 11.3477 - val_bias: -5.9722e-01 - val_resolution: 3.2680 - 576ms/epoch - 2ms/step
# Epoch 19/50
# 282/282 - 1s - loss: 13.3499 - bias: 0.0728 - resolution: 3.5825 - val_loss: 8.9824 - val_bias: 0.2908 - val_resolution: 2.9468 - 572ms/epoch - 2ms/step
# Epoch 20/50
# 282/282 - 1s - loss: 12.8914 - bias: 0.0769 - resolution: 3.5357 - val_loss: 9.5594 - val_bias: -4.1562e-01 - val_resolution: 3.0194 - 573ms/epoch - 2ms/step
# Epoch 21/50
# 282/282 - 1s - loss: 13.0701 - bias: 0.0802 - resolution: 3.5562 - val_loss: 8.6433 - val_bias: 0.2102 - val_resolution: 2.8903 - 581ms/epoch - 2ms/step
# Epoch 22/50
# 282/282 - 1s - loss: 12.8021 - bias: 0.0754 - resolution: 3.5031 - val_loss: 8.7880 - val_bias: 0.0251 - val_resolution: 2.9303 - 577ms/epoch - 2ms/step
# Epoch 23/50
# 282/282 - 1s - loss: 12.5707 - bias: 0.0766 - resolution: 3.4757 - val_loss: 10.2887 - val_bias: -4.2508e-01 - val_resolution: 3.1427 - 580ms/epoch - 2ms/step
# Epoch 24/50
# 282/282 - 1s - loss: 12.3879 - bias: 0.0763 - resolution: 3.4731 - val_loss: 11.2950 - val_bias: 0.0562 - val_resolution: 3.3147 - 588ms/epoch - 2ms/step
# Epoch 25/50
# 282/282 - 1s - loss: 12.4748 - bias: 0.0784 - resolution: 3.4611 - val_loss: 9.2598 - val_bias: -3.2827e-01 - val_resolution: 2.9953 - 603ms/epoch - 2ms/step
# Epoch 26/50
# 282/282 - 1s - loss: 12.1270 - bias: 0.0790 - resolution: 3.4182 - val_loss: 11.0593 - val_bias: 0.1788 - val_resolution: 3.2730 - 587ms/epoch - 2ms/step
# Epoch 27/50
# 282/282 - 1s - loss: 11.9533 - bias: 0.0773 - resolution: 3.3971 - val_loss: 8.4456 - val_bias: -1.0658e-01 - val_resolution: 2.8665 - 602ms/epoch - 2ms/step
# Epoch 28/50
# 282/282 - 1s - loss: 12.1195 - bias: 0.0723 - resolution: 3.4213 - val_loss: 8.6789 - val_bias: 0.7816 - val_resolution: 2.8081 - 589ms/epoch - 2ms/step
# Epoch 29/50
# 282/282 - 1s - loss: 11.8339 - bias: 0.0735 - resolution: 3.3791 - val_loss: 8.4492 - val_bias: 0.3343 - val_resolution: 2.8492 - 589ms/epoch - 2ms/step
# Epoch 30/50
# 282/282 - 1s - loss: 11.6424 - bias: 0.0764 - resolution: 3.3583 - val_loss: 9.0275 - val_bias: -1.1272e-02 - val_resolution: 2.9648 - 587ms/epoch - 2ms/step
# Epoch 31/50
# 282/282 - 1s - loss: 11.7281 - bias: 0.0747 - resolution: 3.3559 - val_loss: 8.1543 - val_bias: -3.5054e-01 - val_resolution: 2.8069 - 588ms/epoch - 2ms/step
# Epoch 32/50
# 282/282 - 1s - loss: 11.2782 - bias: 0.0674 - resolution: 3.3004 - val_loss: 9.4201 - val_bias: 0.3579 - val_resolution: 3.0156 - 584ms/epoch - 2ms/step
# Epoch 33/50
# 282/282 - 1s - loss: 11.5691 - bias: 0.0729 - resolution: 3.3378 - val_loss: 9.0993 - val_bias: -3.1718e-01 - val_resolution: 2.9560 - 608ms/epoch - 2ms/step
# Epoch 34/50
# 282/282 - 1s - loss: 11.5285 - bias: 0.0723 - resolution: 3.3362 - val_loss: 10.3342 - val_bias: 0.5220 - val_resolution: 3.1265 - 621ms/epoch - 2ms/step
# Epoch 35/50
# 282/282 - 1s - loss: 11.4974 - bias: 0.0747 - resolution: 3.3297 - val_loss: 8.4883 - val_bias: -6.8385e-02 - val_resolution: 2.8910 - 624ms/epoch - 2ms/step
# Epoch 36/50
# 282/282 - 1s - loss: 11.0463 - bias: 0.0718 - resolution: 3.2723 - val_loss: 8.2541 - val_bias: -2.7548e-01 - val_resolution: 2.8189 - 625ms/epoch - 2ms/step
# Epoch 37/50
# 282/282 - 1s - loss: 11.0601 - bias: 0.0733 - resolution: 3.2664 - val_loss: 9.0885 - val_bias: 0.6898 - val_resolution: 2.8967 - 602ms/epoch - 2ms/step
# Epoch 38/50
# 282/282 - 1s - loss: 10.9887 - bias: 0.0725 - resolution: 3.2691 - val_loss: 8.3050 - val_bias: -1.0889e-01 - val_resolution: 2.8449 - 611ms/epoch - 2ms/step
# Epoch 39/50
# 282/282 - 1s - loss: 10.9330 - bias: 0.0713 - resolution: 3.2586 - val_loss: 9.9634 - val_bias: -9.8107e-01 - val_resolution: 2.9560 - 616ms/epoch - 2ms/step
# Epoch 40/50
# 282/282 - 1s - loss: 11.1136 - bias: 0.0734 - resolution: 3.2677 - val_loss: 8.9736 - val_bias: -3.1949e-02 - val_resolution: 2.9494 - 598ms/epoch - 2ms/step
# Epoch 41/50
# 282/282 - 1s - loss: 10.7756 - bias: 0.0715 - resolution: 3.2381 - val_loss: 9.2454 - val_bias: -1.2719e-01 - val_resolution: 2.9972 - 594ms/epoch - 2ms/step
# Epoch 42/50
# 282/282 - 1s - loss: 11.0916 - bias: 0.0700 - resolution: 3.2756 - val_loss: 8.8999 - val_bias: -1.7431e-01 - val_resolution: 2.9411 - 587ms/epoch - 2ms/step
# Epoch 43/50
# 282/282 - 1s - loss: 10.9509 - bias: 0.0723 - resolution: 3.2599 - val_loss: 8.4798 - val_bias: -2.3168e-01 - val_resolution: 2.8605 - 584ms/epoch - 2ms/step
# Epoch 44/50
# 282/282 - 1s - loss: 10.6147 - bias: 0.0666 - resolution: 3.2023 - val_loss: 9.6203 - val_bias: 0.2509 - val_resolution: 3.0516 - 589ms/epoch - 2ms/step
# Epoch 45/50
# 282/282 - 1s - loss: 10.6841 - bias: 0.0666 - resolution: 3.2099 - val_loss: 10.5692 - val_bias: 0.1174 - val_resolution: 3.1951 - 596ms/epoch - 2ms/step
# Epoch 46/50
# 282/282 - 1s - loss: 10.8002 - bias: 0.0743 - resolution: 3.2347 - val_loss: 9.1207 - val_bias: -1.4465e-01 - val_resolution: 2.9863 - 590ms/epoch - 2ms/step
# Epoch 47/50
# 282/282 - 1s - loss: 10.4932 - bias: 0.0659 - resolution: 3.1808 - val_loss: 7.8889 - val_bias: -2.8854e-02 - val_resolution: 2.7768 - 602ms/epoch - 2ms/step
# Epoch 48/50
# 282/282 - 1s - loss: 10.1275 - bias: 0.0724 - resolution: 3.1315 - val_loss: 7.5631 - val_bias: 0.2718 - val_resolution: 2.7039 - 709ms/epoch - 3ms/step
# Epoch 49/50
# 282/282 - 1s - loss: 10.3968 - bias: 0.0684 - resolution: 3.1753 - val_loss: 9.0233 - val_bias: 0.7462 - val_resolution: 2.8680 - 696ms/epoch - 2ms/step
# Epoch 50/50
# 282/282 - 1s - loss: 10.3977 - bias: 0.0680 - resolution: 3.1848 - val_loss: 8.3504 - val_bias: 0.3455 - val_resolution: 2.8306 - 616ms/epoch - 2ms/step

# %% [markdown]
# ### Plot training curves

# %%
fig, ax = plt.subplots(1, figsize=(8,5))
n = np.arange(len(fit.history['loss']))

ax.plot(n, fit.history['loss'], ls='--', c='royalblue', label='loss')
ax.plot(n, fit.history['val_loss'], label='val_loss', c='blue')

ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend()
ax.semilogy()
ax.grid()
plt.show()

# %% [markdown]
# ---
# ### Performance of the DNN
# After training the model, we can use the test set `X_test` to evaluate the performance of the DNN. Particularly interesting are the resolution and the bias of the method. A bias close to 0 is desirable. A resolution below 3 EeV can be regarded as good.

# %%
energy_pred = model.predict(X_test, batch_size=128, verbose=1)[:,0]
# Out:
# 157/157 [==============================] - 0s 713us/step

# %%
diff = energy_pred - energy_test
resolution = np.std(diff)
plt.figure()
plt.hist(diff, bins=100)
plt.xlabel('$E_\mathrm{rec} - E_\mathrm{true}$')
plt.ylabel('# Events')
plt.text(0.95, 0.95, '$\sigma = %.3f$ EeV' % resolution, ha='right', va='top', transform=plt.gca().transAxes)
plt.text(0.95, 0.85, '$\mu = %.1f$ EeV' % diff.mean(), ha='right', va='top', transform=plt.gca().transAxes)
plt.grid()
plt.xlim(-10, 10)
plt.tight_layout()

# %% [markdown]
# After estimating the bias and the resolution, we can now inspect the reconstruction via a scatter plot. Furthermore, we can study the energy dependence of the resolution. With increasing energy, the performance increases due to the lower sampling fluctuation of the ground-based particle detectors and the larger footprints.

# %%
x = [3, 10, 30, 100]
labels = ["3", "10", "30", "100"]

diff = energy_pred - energy_test

# Embedding plot
fig, axes = plt.subplots(1, 2, figsize=(20, 9))
axes[0].scatter(energy_test, energy_pred, s=3, alpha=0.60)
axes[0].set_xlabel(r"$E_{true}\;/\;\mathrm{EeV}$")
axes[0].set_ylabel(r"$E_{DNN}\;/\;\mathrm{EeV}$")

stat_box = r"$\mu = $ %.3f" % np.mean(diff) + " / EeV" + "\n" + "$\sigma = $ %.3f" % np.std(diff) + " / EeV"
axes[0].text(0.95, 0.2, stat_box, verticalalignment="top", horizontalalignment="right",
          transform=axes[0].transAxes, backgroundcolor="w")
axes[0].plot([np.min(energy_test), np.max(energy_test)],
             [np.min(energy_test), np.max(energy_test)], color="red")

sns.regplot(x=energy_test, y=diff / energy_test, x_estimator=np.std, x_bins=12,
            fit_reg=False, color="royalblue", ax=axes[1])
axes[1].tick_params(axis="both", which="major")
axes[1].set(xscale="log")
plt.xticks(x, labels)

axes[1].set_xlabel(r"$E_{true}\;/\;\mathrm{EeV}$")
axes[1].set_ylabel(r"$\sigma_{E}/E$")
axes[1].set_ylim(0, 0.2)
plt.show()
